# %%
import pandas

# %%
pandas.read_csv('/Users/daniel.brichler/projects/finance/data/Gasoline RBOB Futures Historical Data.csv')
# Out:
#              Date   Price    Open    High     Low    Vol. Change %
# 0    Jul 27, 2022  3.1257  3.1006  3.1376  3.0793       -    1.42%
# 1    Jul 26, 2022  3.0818  3.1021  3.1934  3.0417   7.89K   -1.11%
# 2    Jul 25, 2022  3.1163  2.9957  3.1258  2.9783   6.01K    3.20%
# 3    Jul 24, 2022  3.0198  3.2321  3.2367  3.0191       -   -0.23%
# 4    Jul 22, 2022  3.0268  2.9882  3.0655  2.9383   6.82K    0.96%
# ..            ...     ...     ...     ...     ...     ...      ...
# 641  Jul 02, 2020  1.3390  1.2222  1.2625  1.2092  59.41K    1.99%
# 642  Jul 01, 2020  1.3129  1.2193  1.2497  1.1920  63.02K    0.98%
# 643  Jun 30, 2020  1.3002  1.1900  1.2182  1.1795   4.24K   -0.71%
# 644  Jun 29, 2020  1.3095  1.2800  1.2800  1.2800   0.00K   15.63%
# 645  Jun 28, 2020  1.1325  1.1355  1.1385  1.1285       -  -11.91%
#
# [646 rows x 7 columns]
